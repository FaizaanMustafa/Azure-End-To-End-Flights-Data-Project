# %%
array = [
    {
        "container":"flights",
        "source_folder":"raw",
        "source_directory":"airports",
        "target_folder":"bronze",
        "target_directory":"airports"
    },
     {
        "container":"flights",
        "source_folder":"raw",
        "source_directory":"bokings",
        "target_folder":"bronze",
        "target_directory":"bookings"
    },
    {
        "container":"flights",
        "source_folder":"raw",
        "source_directory":"flights",
        "target_folder":"bronze",
        "target_directory":"flights"
    },
    {
        "container":"flights",
        "source_folder":"raw",
        "source_directory":"passengers",
        "target_folder":"bronze",
        "target_directory":"passengers"
    },

]

# %%
dbutils.jobs.taskValues.set(key = 'data',value = array)
